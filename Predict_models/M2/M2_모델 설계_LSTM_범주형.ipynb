# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import pymysql
from dotenv import load_dotenv
import os
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adam
plt.rc('font', family = 'Hancom Gothic')

# %%
# 하이퍼파라미터
my_patience = 30
my_epochs = 1000
my_optimizer = Adam(learning_rate=0.00001)
my_batch_size = 100 # 작게 하면 더 미세하게 학습, 크게 하면 빠르고 덜 세밀

# %% [markdown]
# # 데이터 체크

# %%
load_dotenv()
host = os.getenv('host')
user = os.getenv('user')
password = os.getenv('password')
database = os.getenv('database')
port = int(os.getenv('port', 3306))

query =f"""
    SELECT *
    FROM basic_data"""

try:
    connection = pymysql.connect(
        host=host,
        user=user,
        password=password,
        database=database,
        port=port,
        charset='utf8mb4',
        cursorclass=pymysql.cursors.DictCursor
    )
    with connection.cursor() as cursor:
        cursor.execute(query)
        data = cursor.fetchall()
        whole_data = pd.DataFrame(data)
except Exception as e:
    print('에러 발생:', e)
finally:
    try:
        connection.close()
    except:
        pass

# %%
whole_data[whole_data['year']!=2025].isna().sum() # 학습에 사용할 데이터 : 21 ~ 24년 데이터, 결측치 X
# Out:
# year                0
# month               0
# day                 0
# hour                0
# district            0
# datetime            0
# total_population    0
# season              0
# commute_time        0
# weekend_flag        0
# precipitation       0
# temperature         0
# humidity            0
# wind_speed          0
# rental_count        0
# dtype: int64

# %%
# PM데이터 로드
df_pm = pd.read_csv('PM_data/서울시_시간별_PM_배치_2021_2025.csv', parse_dates=['일시'])
df_pm.columns =['일시','행정구','PM대여량']

# %%
df_pm.isna().sum() # 결측치 0건
# Out:
# 일시       0
# 행정구      0
# PM대여량    0
# dtype: int64

# %%
# 데이터 concat
whole_data.columns = ['연도','월','일','시','행정구','일시','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량']

# %%
whole_data = whole_data[whole_data['연도']!=2025]
whole_data.shape
# Out:
# (872093, 15)

# %%
whole_data.info()
df_pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872093 entries, 0 to 872092
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   연도        872093 non-null  int64
#  1   월         872093 non-null  int64
#  2   일         872093 non-null  int64
#  3   시         872093 non-null  int64
#  4   행정구       872093 non-null  object
#  5   일시        872093 non-null  datetime64[ns]
#  6   총생활인구수    872093 non-null  int64
#  7   계절        872093 non-null  object
#  8   출퇴근시간여부   872093 non-null  object
#  9   주말구분      872093 non-null  int64
#  10  강수        872093 non-null  float64
#  11  기온        872093 non-null  float64
#  12  습도        872093 non-null  float64
#  13  풍속        872093 non-null  float64
#  14  공공자전거대여량  872093 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(3)
# memory usage: 106.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832656 entries, 0 to 832655
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   일시      832656 non-null  datetime64[ns]
#  1   행정구     832656 non-null  object
#  2   PM대여량   832656 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 19.1+ MB

# %%
df_total = whole_data.merge(df_pm, on=['행정구','일시'])
df_total
# Out:
#           연도   월   일   시   행정구                  일시  총생활인구수  계절 출퇴근시간여부  주말구분  \
# 0       2021   1   1   0   강남구 2021-01-01 00:00:00  618455  겨울      기타     0
# 1       2021   1   1   0   강동구 2021-01-01 00:00:00  525221  겨울      기타     0
# 2       2021   1   1   0   강북구 2021-01-01 00:00:00  321499  겨울      기타     0
# 3       2021   1   1   0   강서구 2021-01-01 00:00:00  547288  겨울      기타     0
# 4       2021   1   1   0   관악구 2021-01-01 00:00:00  492742  겨울      기타     0
# ...      ...  ..  ..  ..   ...                 ...     ...  ..     ...   ...
# 662781  2024  12  31  23   송파구 2024-12-31 23:00:00  718964  겨울      기타     0
# 662782  2024  12  31  23   양천구 2024-12-31 23:00:00  378141  겨울      기타     0
# 662783  2024  12  31  23  영등포구 2024-12-31 23:00:00  420498  겨울      기타     0
# 662784  2024  12  31  23   은평구 2024-12-31 23:00:00  453206  겨울      기타     0
# 662785  2024  12  31  23   은평구 2024-12-31 23:00:00  453206  겨울      기타     0
#
#          강수   기온    습도   풍속  공공자전거대여량  PM대여량
# 0       0.0 -4.2  59.0  1.4       9.0     24
# 1       0.0 -6.6  60.0  1.4      12.0     21
# 2       0.0 -5.4  54.0  1.1      12.0      3
# 3       0.0 -3.3  52.0  0.9      27.0      3
# 4       0.0 -2.5  50.0  0.9      19.0     18
# ...     ...  ...   ...  ...       ...    ...
# 662781  0.0  0.5  61.0  1.3     115.0     37
# 662782  0.0  1.7  63.0  1.8     101.0     16
# 662783  0.0  1.3  62.0  1.2     113.0      6
# 662784  0.0  0.3  62.0  1.3      35.0      5
# 662785  0.0  0.3  62.0  1.3      35.0     52
#
# [662786 rows x 16 columns]

# %%
df_total[df_total.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [연도, 월, 일, 시, 행정구, 일시, 총생활인구수, 계절, 출퇴근시간여부, 주말구분, 강수, 기온, 습도, 풍속, 공공자전거대여량, PM대여량]
# Index: []

# %%
# feature 추출
# 시계열 요소
import holidays
kr_holidays = holidays.KR(years=[2021, 2024])
df_total['공휴일'] = df_total['일시'].dt.date.isin(kr_holidays).astype(int)
# df_total
cols_time = ['연도','월','일','시','계절','출퇴근시간여부','주말구분','공휴일']

# %% [markdown]
# # 라벨인코더

# %%
# 라벨 인코딩
from sklearn.preprocessing import LabelEncoder
le_season = LabelEncoder()
le_commute = LabelEncoder()
le_gu = LabelEncoder()
df_total['계절'] = le_season.fit_transform(df_total['계절'].values)
df_total['출퇴근시간여부'] = le_commute.fit_transform(df_total['출퇴근시간여부'].values)
df_total['행정구'] = le_gu.fit_transform(df_total['행정구'].values)
df_total
# Out:
#           연도   월   일   시  행정구                  일시  총생활인구수  계절  출퇴근시간여부  주말구분  \
# 0       2021   1   1   0    0 2021-01-01 00:00:00  618455   1        0     0
# 1       2021   1   1   0    1 2021-01-01 00:00:00  525221   1        0     0
# 2       2021   1   1   0    2 2021-01-01 00:00:00  321499   1        0     0
# 3       2021   1   1   0    3 2021-01-01 00:00:00  547288   1        0     0
# 4       2021   1   1   0    4 2021-01-01 00:00:00  492742   1        0     0
# ...      ...  ..  ..  ..  ...                 ...     ...  ..      ...   ...
# 662781  2024  12  31  23   14 2024-12-31 23:00:00  718964   1        0     0
# 662782  2024  12  31  23   15 2024-12-31 23:00:00  378141   1        0     0
# 662783  2024  12  31  23   16 2024-12-31 23:00:00  420498   1        0     0
# 662784  2024  12  31  23   17 2024-12-31 23:00:00  453206   1        0     0
# 662785  2024  12  31  23   17 2024-12-31 23:00:00  453206   1        0     0
#
#          강수   기온    습도   풍속  공공자전거대여량  PM대여량  공휴일
# 0       0.0 -4.2  59.0  1.4       9.0     24    1
# 1       0.0 -6.6  60.0  1.4      12.0     21    1
# 2       0.0 -5.4  54.0  1.1      12.0      3    1
# 3       0.0 -3.3  52.0  0.9      27.0      3    1
# 4       0.0 -2.5  50.0  0.9      19.0     18    1
# ...     ...  ...   ...  ...       ...    ...  ...
# 662781  0.0  0.5  61.0  1.3     115.0     37    0
# 662782  0.0  1.7  63.0  1.8     101.0     16    0
# 662783  0.0  1.3  62.0  1.2     113.0      6    0
# 662784  0.0  0.3  62.0  1.3      35.0      5    0
# 662785  0.0  0.3  62.0  1.3      35.0     52    0
#
# [662786 rows x 17 columns]

# %% [markdown]
# # PM운영 행정구와 전체 행정구 체크
# - PM의 경우 서울시에 운영현황을 공유한 회사만 체크

# %%
df_total['행정구'].unique()
pm_gu_list = le_gu.classes_.tolist()

# %%
gu_list = whole_data['행정구'].unique().tolist()

# %% [markdown]
# # 스케일 조정
# - 시계열 내용 time_cols = ['연도','월','일','시','계절','출퇴근시간여부','주말구분','공휴일'] 를 제외 나머지 연속형 데이터 스케일 조정

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
cols_scale = ['총생활인구수', '강수', '기온','습도','풍속','공공자전거대여량'] # 독립변수만
df_total[cols_scale] = scaler.fit_transform(df_total[cols_scale].values)
df_total
# Out:
#           연도   월   일   시  행정구                  일시    총생활인구수  계절  출퇴근시간여부  \
# 0       2021   1   1   0    0 2021-01-01 00:00:00  0.431544   1        0
# 1       2021   1   1   0    1 2021-01-01 00:00:00  0.342346   1        0
# 2       2021   1   1   0    2 2021-01-01 00:00:00  0.147441   1        0
# 3       2021   1   1   0    3 2021-01-01 00:00:00  0.363457   1        0
# 4       2021   1   1   0    4 2021-01-01 00:00:00  0.311272   1        0
# ...      ...  ..  ..  ..  ...                 ...       ...  ..      ...
# 662781  2024  12  31  23   14 2024-12-31 23:00:00  0.527703   1        0
# 662782  2024  12  31  23   15 2024-12-31 23:00:00  0.201632   1        0
# 662783  2024  12  31  23   16 2024-12-31 23:00:00  0.242155   1        0
# 662784  2024  12  31  23   17 2024-12-31 23:00:00  0.273448   1        0
# 662785  2024  12  31  23   17 2024-12-31 23:00:00  0.273448   1        0
#
#         주말구분        강수        기온        습도        풍속  공공자전거대여량  PM대여량  공휴일
# 0          0  0.011628  0.519864  0.594059  0.210526  0.002456     24    1
# 1          0  0.011628  0.492622  0.603960  0.210526  0.003377     21    1
# 2          0  0.011628  0.506243  0.544554  0.184211  0.003377      3    1
# 3          0  0.011628  0.530079  0.524752  0.166667  0.007983      3    1
# 4          0  0.011628  0.539160  0.504950  0.166667  0.005527     18    1
# ...      ...       ...       ...       ...       ...       ...    ...  ...
# 662781     0  0.011628  0.573212  0.613861  0.201754  0.035002     37    0
# 662782     0  0.011628  0.586833  0.633663  0.245614  0.030703     16    0
# 662783     0  0.011628  0.582293  0.623762  0.192982  0.034387      6    0
# 662784     0  0.011628  0.570942  0.623762  0.201754  0.010439      5    0
# 662785     0  0.011628  0.570942  0.623762  0.201754  0.010439     52    0
#
# [662786 rows x 17 columns]

# %%
# 1. 1년 전 '연도', '월', '일', '시' 컬럼 생성
df_total['1년전_연도'] = df_total['연도'] - 1

# 2. merge용 key 생성
merge_cols = ['행정구', '1년전_연도', '월', '일', '시']
df_total['merge_key'] = df_total['행정구'].astype(str) + '_' + (df_total['연도']-1).astype(str) + '_' + df_total['월'].astype(str) + '_' + df_total['일'].astype(str) + '_' + df_total['시'].astype(str)

df_total['now_key'] = df_total['행정구'].astype(str) + '_' + df_total['연도'].astype(str) + '_' + df_total['월'].astype(str) + '_' + df_total['일'].astype(str) + '_' + df_total['시'].astype(str)

df_yearago = df_total[['now_key', '총생활인구수', 'PM대여량']].copy()
df_yearago.columns = ['merge_key', '1년전_총생활인구수', '1년전_PM대여량']

df_total = df_total.merge(df_yearago, on='merge_key', how='left')
df_total = df_total.dropna().drop(['merge_key', 'now_key','1년전_연도'],axis=1)

# %% [markdown]
# # 타겟변수 범주화

# %% [markdown]
# ## 범주 기준 clustering

# %%
print('타겟변수 최대값 :',df_total['PM대여량'].max())
print('타겟변수 최소값 :',df_total['PM대여량'].min())
print('타겟변수 평균 :',df_total['PM대여량'].mean())
print('타겟변수 표준편차 :',df_total['PM대여량'].std())
display(df_total['PM대여량'].describe())
# Out:
# 타겟변수 최대값 : 167
# 타겟변수 최소값 : 3
# 타겟변수 평균 : 28.435073610833772
# 타겟변수 표준편차 : 24.659611717346884
# count    550870.000000
# mean         28.435074
# std          24.659612
# min           3.000000
# 25%           9.000000
# 50%          22.000000
# 75%          39.000000
# max         167.000000
# Name: PM대여량, dtype: float64

# %% [markdown]
# ### cluster용 샘플 데이터 1.
# - 50개 단위로 끊어서 시계열 유지

# %%
sample_data = df_total[::50]
sample_data.shape
# Out:
# (11018, 19)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

for n_clusters in range(2,10) :
    cluster = KMeans(n_clusters=n_clusters,
                  n_init = 10,)
    cluster.fit(sample_data[['연도','월','일','시','행정구','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']].values)
    pred = cluster.labels_
    score = silhouette_score(X = sample_data[['연도','월','일','시','행정구','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']],
                            labels = pred)
    print(f"클러스트수 : {n_clusters}, 실루엣 계수 : {score}")
# Out:
# 클러스트수 : 2, 실루엣 계수 : 0.5034152029287449
# 클러스트수 : 3, 실루엣 계수 : 0.35829080766409677
# 클러스트수 : 4, 실루엣 계수 : 0.2928090306335364
# 클러스트수 : 5, 실루엣 계수 : 0.25021259315453737
# 클러스트수 : 6, 실루엣 계수 : 0.24037891458352895
# 클러스트수 : 7, 실루엣 계수 : 0.23465306470953057
# 클러스트수 : 8, 실루엣 계수 : 0.2252786575537092
# 클러스트수 : 9, 실루엣 계수 : 0.21832308531956343

# %% [markdown]
# ### cluster용 샘플 데이터 2.
# - 1개월 단위로 샘플링
# - 연단위의 경우 데이터의 과다(18만개)로 메모리 이슈 발생

# %%
del sample_data

# %%
sample_data = df_total[df_total['월']==7]
sample_data.shape
# Out:
# (47221, 19)

# %%
for n_clusters in range(2,10) :
    cluster = KMeans(n_clusters=n_clusters,
                  n_init = 10,)
    cluster.fit(sample_data[['연도','월','일','시','행정구','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']].values)
    pred = cluster.labels_
    score = silhouette_score(X = sample_data[['연도','월','일','시','행정구','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']],
                            labels = pred)
    print(f"클러스트수 : {n_clusters}, 실루엣 계수 : {score}")
# Out:
# 클러스트수 : 2, 실루엣 계수 : 0.50380245956795
# 클러스트수 : 3, 실루엣 계수 : 0.3571750579350531
# 클러스트수 : 4, 실루엣 계수 : 0.31127190214918143
# 클러스트수 : 5, 실루엣 계수 : 0.2703939030900694
# 클러스트수 : 6, 실루엣 계수 : 0.27035878459618323
# 클러스트수 : 7, 실루엣 계수 : 0.26017600961164794
# 클러스트수 : 8, 실루엣 계수 : 0.25187154305100445
# 클러스트수 : 9, 실루엣 계수 : 0.244388411222825

# %% [markdown]
# ### cluster용 샘플 데이터 3.
# - 1년 단위로 샘플링
# - feature 축소를 통해 메모리 부족 해소

# %%
del sample_data

# %%
sample_data = df_total[df_total['월']==7]
sample_data.shape
# Out:
# (47221, 19)

# %%
for n_clusters in range(2,10) :
    cluster = KMeans(n_clusters=n_clusters,
                  n_init = 10,)
    input_data = sample_data[['연도','월','일','시','행정구','총생활인구수','강수','기온','습도','풍속','공공자전거대여량','1년전_총생활인구수','1년전_PM대여량']].values
    cluster.fit(input_data)
    pred = cluster.labels_
    score = silhouette_score(X = input_data,
                            labels = pred)
    print(f"클러스트수 : {n_clusters}, 실루엣 계수 : {score}")
# Out:
# 클러스트수 : 2, 실루엣 계수 : 0.5020230718545858
# 클러스트수 : 3, 실루엣 계수 : 0.3587312000312493
# 클러스트수 : 4, 실루엣 계수 : 0.3121305262017013
# 클러스트수 : 5, 실루엣 계수 : 0.2713132441876673
# 클러스트수 : 6, 실루엣 계수 : 0.2714484744987242
# 클러스트수 : 7, 실루엣 계수 : 0.2613360692833384
# 클러스트수 : 8, 실루엣 계수 : 0.2532321690074345
# 클러스트수 : 9, 실루엣 계수 : 0.2457243502992503

# %% [markdown]
# # 실루엣 계수 분석
# ```
# count    550870.000000
# mean         28.435074
# std          24.659612
# min           3.000000
# 25%           9.000000
# 50%          22.000000
# 75%          39.000000
# max         167.000000
# ```
# - cluster가 2~3 개일 때 실루엣계수가 가장 높으나
# - 실질적으로 PM을 재배치하기에 구간을 분배하기 위한 조건으로는 부족함.
# - 평균이 28이고 Q3가 39인 것을 고려하여 수동 bin 배분이 필요하다고 사료됨.
# - 범주는 4분위 수와 편차를 기준으로 아래와 같이 구분하여 학습
#     * 0~9 공급과다
#     * 9~39 공급평균
#     * 39 ~ 65 공급다소부족
#     * 65 ~ 90 공급부족
#     * 90 + 공급절대 부족 5개 구간으로 분리

# %%
import numpy as np
import pandas as pd
# 타겟변수 범주화
bins = [0, 9, 39, 65, 90, np.inf]
num_bins = len(bins)
labels = ['공급과다', '공급평균', '공급다소부족', '공급부족', '공급절대부족']

# 'PM대여량'을 구간화해서 범주 label로 변환
df_total['PM대여량_class'] = pd.cut(
    df_total['PM대여량'],
    bins=bins,
    labels=labels,
    right=False  # 9, 39, 65, 90은 각 구간의 시작값 포함, 끝값은 미포함
)

# 결과 확인
print(df_total['PM대여량_class'].value_counts())

df_total['PM대여량_class'].value_counts(sort=False).plot(kind='bar')
plt.title('대여량 클래스별 샘플수 (qcut)')
plt.xlabel('대여량 클래스 index')
plt.ylabel('샘플 수')
plt.show()
# Out:
# 공급평균      282760
# 공급과다      126135
# 공급다소부족     87145
# 공급부족       38002
# 공급절대부족     16828
# Name: PM대여량_class, dtype: int64

# %% [markdown]
# ## 데이터의 불균형이 발생하였으나 절대적인 data의 수가 부족하진 않다고 생각하여 학습 진행

# %%
df_total
# Out:
#           연도   월   일   시  행정구                  일시    총생활인구수  계절  출퇴근시간여부  \
# 165265  2022   1   1   0    0 2022-01-01 00:00:00  0.434509   1        0
# 165266  2022   1   1   0    1 2022-01-01 00:00:00  0.342358   1        0
# 165267  2022   1   1   0    2 2022-01-01 00:00:00  0.136425   1        0
# 165268  2022   1   1   0    3 2022-01-01 00:00:00  0.355300   1        0
# 165269  2022   1   1   0    4 2022-01-01 00:00:00  0.292608   1        0
# ...      ...  ..  ..  ..  ...                 ...       ...  ..      ...
# 718226  2024  12  31  23   16 2024-12-31 23:00:00  0.242155   1        0
# 718227  2024  12  31  23   17 2024-12-31 23:00:00  0.273448   1        0
# 718228  2024  12  31  23   17 2024-12-31 23:00:00  0.273448   1        0
# 718229  2024  12  31  23   17 2024-12-31 23:00:00  0.273448   1        0
# 718230  2024  12  31  23   17 2024-12-31 23:00:00  0.273448   1        0
#
#         주말구분        강수        기온        습도        풍속  공공자전거대여량  PM대여량  공휴일  \
# 165265     1  0.011628  0.527809  0.366337  0.210526  0.001228     33    0
# 165266     1  0.011628  0.493757  0.405941  0.192982  0.007062     25    0
# 165267     1  0.011628  0.496027  0.396040  0.157895  0.002763      5    0
# 165268     1  0.011628  0.517594  0.336634  0.219298  0.017808      4    0
# 165269     1  0.011628  0.499432  0.326733  0.245614  0.007676     20    0
# ...      ...       ...       ...       ...       ...       ...    ...  ...
# 718226     0  0.011628  0.582293  0.623762  0.192982  0.034387      6    0
# 718227     0  0.011628  0.570942  0.623762  0.201754  0.010439      5    0
# 718228     0  0.011628  0.570942  0.623762  0.201754  0.010439      5    0
# 718229     0  0.011628  0.570942  0.623762  0.201754  0.010439     52    0
# 718230     0  0.011628  0.570942  0.623762  0.201754  0.010439     52    0
#
#         1년전_총생활인구수  1년전_PM대여량 PM대여량_class
# 165265    0.431544       24.0        공급평균
# 165266    0.342346       21.0        공급평균
# 165267    0.147441        3.0        공급과다
# 165268    0.363457        3.0        공급과다
# 165269    0.311272       18.0        공급평균
# ...            ...        ...         ...
# 718226    0.229339        7.0        공급과다
# 718227    0.270446        7.0        공급과다
# 718228    0.270446       65.0        공급과다
# 718229    0.270446        7.0      공급다소부족
# 718230    0.270446       65.0      공급다소부족
#
# [550870 rows x 20 columns]

# %% [markdown]
# # 타겟변수 라벨인코딩

# %%
from sklearn.preprocessing import LabelEncoder
le_target = LabelEncoder()
df_total['PM대여량_class'] = le_target.fit_transform(df_total['PM대여량_class'].values)
df_total['PM대여량_class']
# Out:
# 165265    4
# 165266    4
# 165267    0
# 165268    0
# 165269    4
#          ..
# 718226    0
# 718227    0
# 718228    0
# 718229    1
# 718230    1
# Name: PM대여량_class, Length: 550870, dtype: int32

# %% [markdown]
# # feature 선정

# %% [markdown]
# ## 상관계수 체크

# %%
import pandas as pd
corrs = df_total.corr(numeric_only=True)
corrs['PM대여량'].sort_values(ascending=False)  # 타겟과의 상관계수
# Out:
# PM대여량          1.000000
# 1년전_PM대여량      0.579309
# 1년전_총생활인구수     0.326858
# 총생활인구수         0.322036
# 출퇴근시간여부        0.169530
# 시              0.153159
# 주말구분           0.145724
# 공공자전거대여량       0.093070
# 습도             0.086837
# 기온             0.083839
# 행정구            0.067721
# 월              0.044868
# PM대여량_class    0.039231
# 계절             0.008641
# 강수             0.003174
# 일              0.001796
# 공휴일           -0.001834
# 연도            -0.002853
# 풍속            -0.108760
# Name: PM대여량, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font',family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

mask = np.triu(np.ones_like(corrs, dtype=bool), k=1)
plt.figure(figsize=(12,10))
sns.heatmap(corrs, annot=True,mask=mask, fmt='.2f', cmap='RdBu_r', vmin=-1, vmax=1)
plt.title('Feature 간 상관계수 히트맵')
plt.show()

# %% [markdown]
# ## 결과에 따라 상관계수가 0에 가까운 순으로 제외 예정
# - 목표 accuracy = 0.75 이상, f1-score, recall/precision 0.7 이상

# %%
corrs['PM대여량'].sort_values(ascending=False).index # 결과에 따라 상관계수가 0에 가까운 순으로 제외 예정
sorted_idx = np.abs(corrs)['PM대여량'].sort_values(ascending=False).index
sorted_idx
# Out:
# Index(['PM대여량', '1년전_PM대여량', '1년전_총생활인구수', '총생활인구수', '출퇴근시간여부', '시', '주말구분',
#        '풍속', '공공자전거대여량', '습도', '기온', '행정구', '월', 'PM대여량_class', '계절', '강수',
#        '연도', '공휴일', '일'],
#       dtype='object')

# %% [markdown]
# ## 데이터 독립변수, 종속변수 분리

# %%
# 독립변수, 종속변수 분리용
# 1차 시도 ['연도','월','일','시','행정구','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']
# 2차 시도 ['연도','월','일','시','행정구','총생활인구수','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']
cols_X = ['연도','월','일','시','행정구','총생활인구수','계절','출퇴근시간여부','주말구분','강수','기온','습도','풍속','공공자전거대여량','공휴일','1년전_총생활인구수','1년전_PM대여량']
cols_y = ['PM대여량_class']
# train_set, val_set, test_set
train_set = df_total[df_total['연도']==2022]
val_set = df_total[df_total['연도']==2023]
test_set = df_total[df_total['연도']==2024]

train_X = np.expand_dims(train_set[cols_X].values,axis=1)
val_X = np.expand_dims(val_set[cols_X].values,axis=1)
test_X = np.expand_dims(test_set[cols_X].values,axis=1)

train_y = train_set[cols_y].values
val_y = val_set[cols_y].values
test_y = test_set[cols_y].values

train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
# Out:
# ((182980, 1, 17),
#  (182980, 1),
#  (183602, 1, 17),
#  (183602, 1),
#  (184288, 1, 17),
#  (184288, 1))

# %% [markdown]
# # 모델 설계

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import Model

# %%
Inp = Input(shape=(train_X.shape[1], train_X.shape[2]))
x = LSTM(512, activation = 'relu', return_sequences=True)(Inp)
x = LSTM(64, activation = 'relu')(x)
Out = Dense(num_bins, activation = 'softmax')(x)

model = Model(inputs = Inp, outputs= Out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 1, 17)]           0
#
#  lstm_14 (LSTM)              (None, 1, 512)            1085440
#
#  lstm_15 (LSTM)              (None, 64)                147712
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 1,233,542
# Trainable params: 1,233,542
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델 학습과정

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=my_optimizer, metrics=['accuracy'])

# %% [markdown]
# # 모델 학습

# %%
es = EarlyStopping(patience=my_patience)
mc = ModelCheckpoint('Backups/loss{val_loss}_accuracy{val_accuracy}_LSTM.h5')

history = model.fit(train_X,train_y,
    epochs=my_epochs,
    verbose='auto',
    callbacks=[es,mc],
    shuffle=False, # 시계열 요소 고려 shuffle = False
    batch_size=my_batch_size,
    validation_data=(val_X,val_y))
# Out:
# Epoch 1/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.8979 - accuracy: 0.6722 - val_loss: 0.9850 - val_accuracy: 0.6428
# Epoch 2/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.7634 - accuracy: 0.7175 - val_loss: 0.9167 - val_accuracy: 0.6565
# Epoch 3/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.7105 - accuracy: 0.7289 - val_loss: 0.8446 - val_accuracy: 0.6701
# Epoch 4/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.6670 - accuracy: 0.7391 - val_loss: 0.7905 - val_accuracy: 0.6775
# Epoch 5/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.6401 - accuracy: 0.7456 - val_loss: 0.7699 - val_accuracy: 0.6842
# Epoch 6/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.6229 - accuracy: 0.7497 - val_loss: 0.7761 - val_accuracy: 0.6857
# Epoch 7/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.6090 - accuracy: 0.7537 - val_loss: 0.7852 - val_accuracy: 0.6901
# Epoch 8/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5966 - accuracy: 0.7561 - val_loss: 0.7945 - val_accuracy: 0.6939
# Epoch 9/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5874 - accuracy: 0.7587 - val_loss: 0.7901 - val_accuracy: 0.6988
# Epoch 10/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5789 - accuracy: 0.7610 - val_loss: 0.7877 - val_accuracy: 0.7040
# Epoch 11/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5713 - accuracy: 0.7625 - val_loss: 0.7818 - val_accuracy: 0.7059
# Epoch 12/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5651 - accuracy: 0.7637 - val_loss: 0.7786 - val_accuracy: 0.7081
# Epoch 13/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5600 - accuracy: 0.7644 - val_loss: 0.7728 - val_accuracy: 0.7106
# Epoch 14/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5552 - accuracy: 0.7655 - val_loss: 0.7727 - val_accuracy: 0.7106
# Epoch 15/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5510 - accuracy: 0.7665 - val_loss: 0.7751 - val_accuracy: 0.7110
# Epoch 16/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5468 - accuracy: 0.7672 - val_loss: 0.7788 - val_accuracy: 0.7105
# Epoch 17/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.5430 - accuracy: 0.7678 - val_loss: 0.7828 - val_accuracy: 0.7108
# Epoch 18/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.5394 - accuracy: 0.7685 - val_loss: 0.7852 - val_accuracy: 0.7116
# Epoch 19/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.5359 - accuracy: 0.7691 - val_loss: 0.7881 - val_accuracy: 0.7127
# Epoch 20/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5327 - accuracy: 0.7698 - val_loss: 0.7870 - val_accuracy: 0.7147
# Epoch 21/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5297 - accuracy: 0.7705 - val_loss: 0.7862 - val_accuracy: 0.7159
# Epoch 22/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5269 - accuracy: 0.7710 - val_loss: 0.7837 - val_accuracy: 0.7178
# Epoch 23/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5239 - accuracy: 0.7719 - val_loss: 0.7822 - val_accuracy: 0.7193
# Epoch 24/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5214 - accuracy: 0.7724 - val_loss: 0.7807 - val_accuracy: 0.7205
# Epoch 25/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5189 - accuracy: 0.7729 - val_loss: 0.7790 - val_accuracy: 0.7218
# Epoch 26/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5166 - accuracy: 0.7736 - val_loss: 0.7766 - val_accuracy: 0.7226
# Epoch 27/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5142 - accuracy: 0.7740 - val_loss: 0.7742 - val_accuracy: 0.7237
# Epoch 28/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5120 - accuracy: 0.7745 - val_loss: 0.7707 - val_accuracy: 0.7251
# Epoch 29/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5098 - accuracy: 0.7753 - val_loss: 0.7739 - val_accuracy: 0.7255
# Epoch 30/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5079 - accuracy: 0.7756 - val_loss: 0.7724 - val_accuracy: 0.7267
# Epoch 31/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5059 - accuracy: 0.7761 - val_loss: 0.7708 - val_accuracy: 0.7273
# Epoch 32/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5040 - accuracy: 0.7765 - val_loss: 0.7679 - val_accuracy: 0.7286
# Epoch 33/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5022 - accuracy: 0.7770 - val_loss: 0.7648 - val_accuracy: 0.7298
# Epoch 34/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.5006 - accuracy: 0.7773 - val_loss: 0.7657 - val_accuracy: 0.7305
# Epoch 35/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4988 - accuracy: 0.7780 - val_loss: 0.7612 - val_accuracy: 0.7319
# Epoch 36/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4972 - accuracy: 0.7783 - val_loss: 0.7553 - val_accuracy: 0.7333
# Epoch 37/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4957 - accuracy: 0.7784 - val_loss: 0.7481 - val_accuracy: 0.7348
# Epoch 38/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4941 - accuracy: 0.7788 - val_loss: 0.7442 - val_accuracy: 0.7357
# Epoch 39/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4925 - accuracy: 0.7792 - val_loss: 0.7375 - val_accuracy: 0.7366
# Epoch 40/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4910 - accuracy: 0.7795 - val_loss: 0.7349 - val_accuracy: 0.7375
# Epoch 41/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4895 - accuracy: 0.7801 - val_loss: 0.7283 - val_accuracy: 0.7386
# Epoch 42/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4881 - accuracy: 0.7806 - val_loss: 0.7227 - val_accuracy: 0.7395
# Epoch 43/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4867 - accuracy: 0.7810 - val_loss: 0.7195 - val_accuracy: 0.7401
# Epoch 44/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4852 - accuracy: 0.7814 - val_loss: 0.7153 - val_accuracy: 0.7409
# Epoch 45/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4839 - accuracy: 0.7818 - val_loss: 0.7044 - val_accuracy: 0.7424
# Epoch 46/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4825 - accuracy: 0.7823 - val_loss: 0.7034 - val_accuracy: 0.7427
# Epoch 47/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4811 - accuracy: 0.7825 - val_loss: 0.6964 - val_accuracy: 0.7440
# Epoch 48/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4798 - accuracy: 0.7832 - val_loss: 0.6911 - val_accuracy: 0.7451
# Epoch 49/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4786 - accuracy: 0.7836 - val_loss: 0.6853 - val_accuracy: 0.7465
# Epoch 50/1000
# 1830/1830 [==============================] - 14s 8ms/step - loss: 0.4773 - accuracy: 0.7841 - val_loss: 0.6780 - val_accuracy: 0.7479
# Epoch 51/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4760 - accuracy: 0.7845 - val_loss: 0.6768 - val_accuracy: 0.7481
# Epoch 52/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4749 - accuracy: 0.7849 - val_loss: 0.6693 - val_accuracy: 0.7499
# Epoch 53/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4736 - accuracy: 0.7855 - val_loss: 0.6629 - val_accuracy: 0.7508
# Epoch 54/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4725 - accuracy: 0.7857 - val_loss: 0.6593 - val_accuracy: 0.7513
# Epoch 55/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4713 - accuracy: 0.7861 - val_loss: 0.6530 - val_accuracy: 0.7520
# Epoch 56/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4702 - accuracy: 0.7862 - val_loss: 0.6476 - val_accuracy: 0.7528
# Epoch 57/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4689 - accuracy: 0.7868 - val_loss: 0.6414 - val_accuracy: 0.7528
# Epoch 58/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4678 - accuracy: 0.7870 - val_loss: 0.6351 - val_accuracy: 0.7528
# Epoch 59/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4667 - accuracy: 0.7874 - val_loss: 0.6315 - val_accuracy: 0.7528
# Epoch 60/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4655 - accuracy: 0.7879 - val_loss: 0.6278 - val_accuracy: 0.7529
# Epoch 61/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4642 - accuracy: 0.7882 - val_loss: 0.6223 - val_accuracy: 0.7536
# Epoch 62/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4629 - accuracy: 0.7883 - val_loss: 0.6202 - val_accuracy: 0.7539
# Epoch 63/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4618 - accuracy: 0.7888 - val_loss: 0.6165 - val_accuracy: 0.7542
# Epoch 64/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4606 - accuracy: 0.7892 - val_loss: 0.6142 - val_accuracy: 0.7545
# Epoch 65/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4595 - accuracy: 0.7895 - val_loss: 0.6100 - val_accuracy: 0.7550
# Epoch 66/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4584 - accuracy: 0.7898 - val_loss: 0.6076 - val_accuracy: 0.7553
# Epoch 67/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4574 - accuracy: 0.7900 - val_loss: 0.6027 - val_accuracy: 0.7562
# Epoch 68/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4563 - accuracy: 0.7904 - val_loss: 0.5993 - val_accuracy: 0.7567
# Epoch 69/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4553 - accuracy: 0.7907 - val_loss: 0.5959 - val_accuracy: 0.7570
# Epoch 70/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4543 - accuracy: 0.7911 - val_loss: 0.5940 - val_accuracy: 0.7573
# Epoch 71/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4532 - accuracy: 0.7916 - val_loss: 0.5909 - val_accuracy: 0.7576
# Epoch 72/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4521 - accuracy: 0.7921 - val_loss: 0.5876 - val_accuracy: 0.7582
# Epoch 73/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4511 - accuracy: 0.7926 - val_loss: 0.5840 - val_accuracy: 0.7586
# Epoch 74/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4501 - accuracy: 0.7931 - val_loss: 0.5835 - val_accuracy: 0.7587
# Epoch 75/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4489 - accuracy: 0.7937 - val_loss: 0.5812 - val_accuracy: 0.7589
# Epoch 76/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4479 - accuracy: 0.7943 - val_loss: 0.5792 - val_accuracy: 0.7593
# Epoch 77/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4467 - accuracy: 0.7951 - val_loss: 0.5774 - val_accuracy: 0.7593
# Epoch 78/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4458 - accuracy: 0.7954 - val_loss: 0.5755 - val_accuracy: 0.7596
# Epoch 79/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4446 - accuracy: 0.7959 - val_loss: 0.5739 - val_accuracy: 0.7597
# Epoch 80/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4436 - accuracy: 0.7965 - val_loss: 0.5729 - val_accuracy: 0.7599
# Epoch 81/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4426 - accuracy: 0.7968 - val_loss: 0.5714 - val_accuracy: 0.7602
# Epoch 82/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4415 - accuracy: 0.7974 - val_loss: 0.5699 - val_accuracy: 0.7608
# Epoch 83/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4405 - accuracy: 0.7978 - val_loss: 0.5686 - val_accuracy: 0.7608
# Epoch 84/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4394 - accuracy: 0.7983 - val_loss: 0.5666 - val_accuracy: 0.7614
# Epoch 85/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4386 - accuracy: 0.7985 - val_loss: 0.5660 - val_accuracy: 0.7617
# Epoch 86/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4376 - accuracy: 0.7990 - val_loss: 0.5650 - val_accuracy: 0.7619
# Epoch 87/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4367 - accuracy: 0.7993 - val_loss: 0.5642 - val_accuracy: 0.7621
# Epoch 88/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.4358 - accuracy: 0.7997 - val_loss: 0.5629 - val_accuracy: 0.7625
# Epoch 89/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4349 - accuracy: 0.8000 - val_loss: 0.5617 - val_accuracy: 0.7628
# Epoch 90/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.4340 - accuracy: 0.8003 - val_loss: 0.5604 - val_accuracy: 0.7632
# Epoch 91/1000
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.4332 - accuracy: 0.8007 - val_loss: 0.5594 - val_accuracy: 0.7633
# Epoch 92/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4323 - accuracy: 0.8010 - val_loss: 0.5576 - val_accuracy: 0.7638
# Epoch 93/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4315 - accuracy: 0.8014 - val_loss: 0.5563 - val_accuracy: 0.7639
# Epoch 94/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4306 - accuracy: 0.8018 - val_loss: 0.5566 - val_accuracy: 0.7640
# Epoch 95/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4299 - accuracy: 0.8020 - val_loss: 0.5548 - val_accuracy: 0.7644
# Epoch 96/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4291 - accuracy: 0.8025 - val_loss: 0.5541 - val_accuracy: 0.7646
# Epoch 97/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4283 - accuracy: 0.8027 - val_loss: 0.5523 - val_accuracy: 0.7652
# Epoch 98/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4275 - accuracy: 0.8031 - val_loss: 0.5525 - val_accuracy: 0.7652
# Epoch 99/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4268 - accuracy: 0.8033 - val_loss: 0.5515 - val_accuracy: 0.7655
# Epoch 100/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4261 - accuracy: 0.8036 - val_loss: 0.5503 - val_accuracy: 0.7659
# Epoch 101/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4253 - accuracy: 0.8038 - val_loss: 0.5505 - val_accuracy: 0.7659
# Epoch 102/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4247 - accuracy: 0.8041 - val_loss: 0.5493 - val_accuracy: 0.7664
# Epoch 103/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4240 - accuracy: 0.8044 - val_loss: 0.5482 - val_accuracy: 0.7667
# Epoch 104/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4233 - accuracy: 0.8047 - val_loss: 0.5480 - val_accuracy: 0.7669
# Epoch 105/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4226 - accuracy: 0.8049 - val_loss: 0.5473 - val_accuracy: 0.7671
# Epoch 106/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4220 - accuracy: 0.8051 - val_loss: 0.5471 - val_accuracy: 0.7672
# Epoch 107/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4214 - accuracy: 0.8054 - val_loss: 0.5463 - val_accuracy: 0.7674
# Epoch 108/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4207 - accuracy: 0.8055 - val_loss: 0.5464 - val_accuracy: 0.7677
# Epoch 109/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4201 - accuracy: 0.8057 - val_loss: 0.5456 - val_accuracy: 0.7680
# Epoch 110/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4195 - accuracy: 0.8060 - val_loss: 0.5451 - val_accuracy: 0.7683
# Epoch 111/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4189 - accuracy: 0.8061 - val_loss: 0.5447 - val_accuracy: 0.7684
# Epoch 112/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4183 - accuracy: 0.8064 - val_loss: 0.5443 - val_accuracy: 0.7687
# Epoch 113/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4178 - accuracy: 0.8066 - val_loss: 0.5447 - val_accuracy: 0.7686
# Epoch 114/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4172 - accuracy: 0.8068 - val_loss: 0.5436 - val_accuracy: 0.7688
# Epoch 115/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4166 - accuracy: 0.8070 - val_loss: 0.5431 - val_accuracy: 0.7688
# Epoch 116/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4162 - accuracy: 0.8071 - val_loss: 0.5430 - val_accuracy: 0.7688
# Epoch 117/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4156 - accuracy: 0.8073 - val_loss: 0.5433 - val_accuracy: 0.7687
# Epoch 118/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4151 - accuracy: 0.8075 - val_loss: 0.5430 - val_accuracy: 0.7686
# Epoch 119/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4146 - accuracy: 0.8077 - val_loss: 0.5423 - val_accuracy: 0.7690
# Epoch 120/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4141 - accuracy: 0.8078 - val_loss: 0.5424 - val_accuracy: 0.7692
# Epoch 121/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4135 - accuracy: 0.8079 - val_loss: 0.5418 - val_accuracy: 0.7695
# Epoch 122/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4131 - accuracy: 0.8080 - val_loss: 0.5420 - val_accuracy: 0.7695
# Epoch 123/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4126 - accuracy: 0.8083 - val_loss: 0.5428 - val_accuracy: 0.7693
# Epoch 124/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4120 - accuracy: 0.8084 - val_loss: 0.5430 - val_accuracy: 0.7693
# Epoch 125/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4115 - accuracy: 0.8085 - val_loss: 0.5432 - val_accuracy: 0.7694
# Epoch 126/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4110 - accuracy: 0.8087 - val_loss: 0.5440 - val_accuracy: 0.7693
# Epoch 127/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4105 - accuracy: 0.8088 - val_loss: 0.5441 - val_accuracy: 0.7694
# Epoch 128/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4101 - accuracy: 0.8089 - val_loss: 0.5446 - val_accuracy: 0.7695
# Epoch 129/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4096 - accuracy: 0.8092 - val_loss: 0.5442 - val_accuracy: 0.7696
# Epoch 130/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4091 - accuracy: 0.8093 - val_loss: 0.5442 - val_accuracy: 0.7696
# Epoch 131/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4086 - accuracy: 0.8094 - val_loss: 0.5442 - val_accuracy: 0.7697
# Epoch 132/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4081 - accuracy: 0.8095 - val_loss: 0.5450 - val_accuracy: 0.7696
# Epoch 133/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4078 - accuracy: 0.8097 - val_loss: 0.5446 - val_accuracy: 0.7697
# Epoch 134/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4074 - accuracy: 0.8096 - val_loss: 0.5448 - val_accuracy: 0.7695
# Epoch 135/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4069 - accuracy: 0.8098 - val_loss: 0.5448 - val_accuracy: 0.7694
# Epoch 136/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4065 - accuracy: 0.8098 - val_loss: 0.5454 - val_accuracy: 0.7693
# Epoch 137/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4059 - accuracy: 0.8102 - val_loss: 0.5450 - val_accuracy: 0.7693
# Epoch 138/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4054 - accuracy: 0.8103 - val_loss: 0.5460 - val_accuracy: 0.7691
# Epoch 139/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4051 - accuracy: 0.8103 - val_loss: 0.5456 - val_accuracy: 0.7690
# Epoch 140/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4047 - accuracy: 0.8104 - val_loss: 0.5437 - val_accuracy: 0.7693
# Epoch 141/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4042 - accuracy: 0.8104 - val_loss: 0.5444 - val_accuracy: 0.7693
# Epoch 142/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4038 - accuracy: 0.8105 - val_loss: 0.5448 - val_accuracy: 0.7691
# Epoch 143/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4033 - accuracy: 0.8105 - val_loss: 0.5447 - val_accuracy: 0.7690
# Epoch 144/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4029 - accuracy: 0.8107 - val_loss: 0.5453 - val_accuracy: 0.7689
# Epoch 145/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4024 - accuracy: 0.8108 - val_loss: 0.5451 - val_accuracy: 0.7689
# Epoch 146/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4021 - accuracy: 0.8110 - val_loss: 0.5459 - val_accuracy: 0.7688
# Epoch 147/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4016 - accuracy: 0.8110 - val_loss: 0.5463 - val_accuracy: 0.7688
# Epoch 148/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4012 - accuracy: 0.8112 - val_loss: 0.5449 - val_accuracy: 0.7690
# Epoch 149/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4008 - accuracy: 0.8113 - val_loss: 0.5457 - val_accuracy: 0.7687
# Epoch 150/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4004 - accuracy: 0.8114 - val_loss: 0.5458 - val_accuracy: 0.7688
# Epoch 151/1000
# 1830/1830 [==============================] - 13s 7ms/step - loss: 0.4000 - accuracy: 0.8117 - val_loss: 0.5462 - val_accuracy: 0.7685

# %%
# 학습과정 그래프를 subplots와 twinx로 시각화
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.plot(history.history['loss'], label='Train Loss', color='tab:blue')
ax1.plot(history.history['val_loss'], label='Val Loss', color='tab:cyan')
ax1.set_ylabel('Loss')
ax1.set_xlabel('Epoch')
ax1.legend(loc='upper left')
ax1.grid(True)
ax2 = ax1.twinx()
ax2.plot(history.history['accuracy'], label='Train Acc', color='tab:orange')
ax2.plot(history.history['val_accuracy'], label='Val Acc', color='tab:red')
ax2.set_ylabel('Accuracy')
ax2.legend(loc='upper right')
plt.title('LSTM Training Loss & Accuracy')
plt.show()

# %% [markdown]
# # 모델의 평가

# %%
loss_and_acc = model.evaluate(test_X,test_y)
# Out:
# 5759/5759 [==============================] - 11s 2ms/step - loss: 0.5795 - accuracy: 0.7560

# %%
test_y
y_hat = model.predict(test_X).argmax(axis=1)
# Out:
# 5759/5759 [==============================] - 7s 1ms/step

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
print('loss :',round(loss_and_acc[0],3))
print('accuracy :',round(loss_and_acc[1],2), '%')
print('precision :',round(precision_score(test_y,y_hat,average='weighted'),2), '%')
print('recall :',round(recall_score(test_y,y_hat,average='weighted'),2), '%')
print('f1_score :',round(f1_score(test_y,y_hat,average='weighted'),2), '%')
# Out:
# loss : 0.579
# accuracy : 0.76 %
# precision : 0.76 %
# recall : 0.76 %
# f1_score : 0.75 %

# %%
import seaborn as sns
crosstab_y = test_y.reshape(-1)
cm_test = pd.crosstab(crosstab_y, y_hat,rownames=['실제값'],colnames=['예측값'])
display(cm_test)
plt.figure(figsize=(9,4))
sns.heatmap(cm_test.values, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix (Test Set)')
plt.xlabel('예측값')
plt.ylabel('실제값')
plt.show()
# Out:
# 예측값      0      1     2     3      4
# 실제값
# 0    36317   1767  1826   205   2314
# 1     3812  18180   905     1   6184
# 2     3047   4319  4246   413    548
# 3      395    130  1762  1734   1640
# 4     8594   3330  1767  2001  78851

# %% [markdown]
# ## 모델평가 : 원하는 accuracy와 recall, precision, f1_score
# - 그러나 가장 중요한 실제값 4(공급 절대 부족)의 경우 0(공급 과다)로 분류하는 경우 경향성

# %%
real_4_predict_value = cm_test.iloc[4,:]
print("공급절대부족_recall :",round(real_4_predict_value.iloc[4] / real_4_predict_value.sum(), 3)*100, "%")
print("공급절대부족 판별이 필요한데 공급과다로 분류 :",round(real_4_predict_value.iloc[0] / real_4_predict_value.sum(), 3)*100, "%")
# Out:
# 공급절대부족_recall : 83.39999999999999 %
# 공급절대부족 판별이 필요한데 공급과다로 분류 : 9.1 %

# %% [markdown]
# ## 공급절대부족 판별이 필요한데 공급과다로 분류 : 9.1%
# * 위 수치를 낮추기 위해
#     1. 다른 모델 활용
#     2. 모델 depth를 더 깊게
#     3. feature 수정

# %% [markdown]
# # 모델 저장

# %%
# 모델, 스케일러, 인코더, feature 리스트 저장
# pm_gu_list : PM운영 행정구
# gu_list : 서울시 전체 행정구
# le_season : 계절 라벨인코더
# le_commute : 출퇴근시간여부 라벨 인코더
# le_gu : 행정구 인코더
# scaler : 독립변수 스케일러 / cols_scale

= ['총생활인구수', '강수', '기온','습도','풍속','공공자전거대여량']
# le_target : 타겟변수 라벨인코더
import joblib
model.save('M2_categorical_DNN.h5')
joblib.dump(pm_gu_list,'M2_ENCODER\PM활용행정구리스트.pkl')
joblib.dump(gu_list, 'M2_ENCODER\서울전역행정구리스트.pkl')
joblib.dump(le_season, 'M2_ENCODER\계절라벨인코더.pkl')
joblib.dump(le_commute, 'M2_ENCODER\출퇴근시간여부라벨인코더.pkl')
joblib.dump(le_gu, 'M2_ENCODER\행정구라벨인코더.pkl')
joblib.dump(cols_scale, 'M2_ENCODER\독립변수리스트.pkl')
joblib.dump(scaler, 'M2_ENCODER\독립변수스케일러.pkl')
# Out:
# ['M2_ENCODER\\독립변수스케일러.pkl']

# %% [markdown]
# # 향후 모델 사용 시 활용 함수

# %%
def class_to_range(pred_class):
    ''' 모델 예측 결과를 범주형 결과로 반환하는 함수 '''
    labels = ['공급과다', '공급평균', '공급다소부족', '공급부족', '공급절대부족']
    pred_class = int(pred_class)
    return labels[pred_class]

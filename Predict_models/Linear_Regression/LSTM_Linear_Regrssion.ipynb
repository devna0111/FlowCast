# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:130px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:130px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import pandas as pd
import numpy as np
import joblib
from datetime import datetime, timedelta
import holidays
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import f1_score,precision_score, recall_score
import seaborn as sns
plt.rc('font',family = 'Hancom Gothic')

# %% [markdown]
# # 데이터 체크 및 전처리

# %%
# 데이터 로딩 및 전처리
df = pd.read_csv('LSTM최종데이터_X_Y_라벨링등전.csv')
df = df.dropna(subset=['대여량']) # 혹시 모를 결측치 제거 코드 _ 결측치 사전 체크 : 결과 0건

df['일시'] = pd.to_datetime(df['일시'])
df['연'] = df['일시'].dt.year
df['월'] = df['일시'].dt.month
df['일'] = df['일시'].dt.day
df['시'] = df['일시'].dt.hour
df['요일'] = df['일시'].dt.dayofweek
start_year = df['연'].min()
end_year = df['연'].max()
kr_holidays = holidays.KR(years=range(start_year, end_year+1)) # 한국 공휴일 체크 라이브러리
df['공휴일'] = df['일시'].dt.floor('D').isin(kr_holidays).astype(int)

df['key'] = df['행정구'] + '_' + df['월'].astype(str) + '_' + df['일'].astype(str) + '_' + df['시'].astype(str)
df['일시_1년전'] = df['일시'] - pd.DateOffset(years=1)
df['key_1년전'] = df['행정구'] + '_' + df['일시_1년전'].dt.month.astype(str) + '_' + df['일시_1년전'].dt.day.astype(str) + '_' + df['일시_1년전'].dt.hour.astype(str)
cols_to_copy = ['대여량', '총생활인구수']
df_1y = df[cols_to_copy].copy()
df_1y.columns = [c + '_1년전' for c in cols_to_copy]
df = pd.concat((df,df_1y), axis=1)
df = df.dropna(subset=['대여량_1년전', '총생활인구수_1년전'])

df
# Out:
#           연도   월   일   시  행정구                  일시   대여량       총생활인구수  계절  \
# 0       2021   1   1   0  강남구 2021-01-01 00:00:00   9.0  618455.4297  겨울
# 1       2021   1   1   0  강동구 2021-01-01 00:00:00  12.0  525220.6638  겨울
# 2       2021   1   1   0  강북구 2021-01-01 00:00:00  12.0  321499.2460  겨울
# 3       2021   1   1   0  강서구 2021-01-01 00:00:00  27.0  547287.6699  겨울
# 4       2021   1   1   0  관악구 2021-01-01 00:00:00  19.0  492742.3420  겨울
# ...      ...  ..  ..  ..  ...                 ...   ...          ...  ..
# 872088  2024  12  31  23  용산구 2024-12-31 23:00:00  37.0  253261.4373  겨울
# 872089  2024  12  31  23  은평구 2024-12-31 23:00:00  35.0  453205.9782  겨울
# 872090  2024  12  31  23  종로구 2024-12-31 23:00:00  81.0  231161.5069  겨울
# 872091  2024  12  31  23   중구 2024-12-31 23:00:00  77.0  172509.0426  겨울
# 872092  2024  12  31  23  중랑구 2024-12-31 23:00:00  57.0  353699.9845  겨울
#
#        출퇴근시간  ...    습도   풍속     연  요일  공휴일           key              일시_1년전  \
# 0         기타  ...  59.0  1.4  2021   4    1     강남구_1_1_0 2020-01-01 00:00:00
# 1         기타  ...  60.0  1.4  2021   4    1     강동구_1_1_0 2020-01-01 00:00:00
# 2         기타  ...  54.0  1.1  2021   4    1     강북구_1_1_0 2020-01-01 00:00:00
# 3         기타  ...  52.0  0.9  2021   4    1     강서구_1_1_0 2020-01-01 00:00:00
# 4         기타  ...  50.0  0.9  2021   4    1     관악구_1_1_0 2020-01-01 00:00:00
# ...      ...  ...   ...  ...   ...  ..  ...           ...                 ...
# 872088    기타  ...  62.0  0.7  2024   1    0  용산구_12_31_23 2023-12-31 23:00:00
# 872089    기타  ...  62.0  1.3  2024   1    0  은평구_12_31_23 2023-12-31 23:00:00
# 872090    기타  ...  68.0  1.7  2024   1    0  종로구_12_31_23 2023-12-31 23:00:00
# 872091    기타  ...  68.0  1.7  2024   1    0   중구_12_31_23 2023-12-31 23:00:00
# 872092    기타  ...  61.0  0.9  2024   1    0  중랑구_12_31_23 2023-12-31 23:00:00
#
#              key_1년전 대여량_1년전   총생활인구수_1년전
# 0          강남구_1_1_0     9.0  618455.4297
# 1          강동구_1_1_0    12.0  525220.6638
# 2          강북구_1_1_0    12.0  321499.2460
# 3          강서구_1_1_0    27.0  547287.6699
# 4          관악구_1_1_0    19.0  492742.3420
# ...              ...     ...          ...
# 872088  용산구_12_31_23    37.0  253261.4373
# 872089  은평구_12_31_23    35.0  453205.9782
# 872090  종로구_12_31_23    81.0  231161.5069
# 872091   중구_12_31_23    77.0  172509.0426
# 872092  중랑구_12_31_23    57.0  353699.9845
#
# [872093 rows x 23 columns]

# %%
# 데이터 전처리 _ 라벨링 및 스케일링
from sklearn.preprocessing import LabelEncoder, StandardScaler
pd.options.mode.copy_on_write = True 
le = LabelEncoder()
df['행정구'] = le.fit_transform(df['행정구'])

feature_cols = [
    '행정구', '월', '일', '시', '요일', '강수', '기온', '습도', '풍속',
    '주말구분', '공휴일',
    '대여량_1년전', '총생활인구수_1년전',
]
X = df[feature_cols]
y = df['대여량']

num_cols = [ '강수', '기온', '습도', '풍속',
    '대여량_1년전', '총생활인구수_1년전',]
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
X.shape, y.shape
# Out:
# ((872093, 13), (872093,))

# %%
# 데이터 분할 : 22년 학습, 23년 검증, 24년 테스트 활용
train_idx = df['연'] == 2022
val_idx = (df['연'] == 2023)
test_idx = (df['연'] == 2024)
X_train, X_val, X_test = X[train_idx], X[val_idx], X[test_idx]
y_train, y_val, y_test = y[train_idx], y[val_idx], y[test_idx]

# %%
# 데이터 LSTM용 설계
X_train = np.expand_dims(X_train,axis=1)
X_val = np.expand_dims(X_val,axis=1)
X_test = np.expand_dims(X_test,axis=1)
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((217520, 1, 13), (218234, 1, 13), (218914, 1, 13))

# %% [markdown]
# # 모델 설계

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM

# 예시: X.shape = (샘플수, time_steps, features)
Inp = Input(shape=(X_train.shape[1], X_train.shape[2]))   # (time_steps, features)

x = LSTM(128, return_sequences=True)(Inp)
x = Dropout(0.2)(x)
x = LSTM(256)(x)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
Out = Dense(1, activation='relu')(x)

model_lstm = Model(inputs=Inp, outputs=Out)

model_lstm.compile(loss='mse', optimizer='adam', metrics=['mae'])

model_lstm.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1, 13)]           0
#
#  lstm_2 (LSTM)               (None, 1, 128)            72704
#
#  dropout_2 (Dropout)         (None, 1, 128)            0
#
#  lstm_3 (LSTM)               (None, 256)               394240
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 508,161
# Trainable params: 508,161
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델 학습

# %%
es = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
mc = ModelCheckpoint('best_lstm_model_lr.h5', monitor='val_loss', save_best_only=True, verbose=1)
history = model_lstm.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_data=(X_val, y_val),
    callbacks=[es, mc],
    verbose=2
)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 475.01031, saving model to best_lstm_model_lr.h5
# 425/425 - 8s - loss: 14667.9971 - mae: 53.8795 - val_loss: 475.0103 - val_mae: 8.3311 - 8s/epoch - 18ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 475.01031 to 229.95323, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 502.4823 - mae: 14.1719 - val_loss: 229.9532 - val_mae: 5.6054 - 3s/epoch - 6ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 229.95323 to 209.16541, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 365.4937 - mae: 11.8906 - val_loss: 209.1654 - val_mae: 9.7144 - 3s/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 209.16541 to 145.19670, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 305.3186 - mae: 10.8143 - val_loss: 145.1967 - val_mae: 7.1470 - 3s/epoch - 6ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 145.19670 to 92.78311, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 267.4097 - mae: 10.0401 - val_loss: 92.7831 - val_mae: 4.2283 - 3s/epoch - 6ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 92.78311 to 89.75907, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 243.1487 - mae: 9.4894 - val_loss: 89.7591 - val_mae: 5.6029 - 3s/epoch - 6ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 89.75907 to 72.05116, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 226.7148 - mae: 9.1409 - val_loss: 72.0512 - val_mae: 4.6437 - 3s/epoch - 6ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 72.05116 to 70.66883, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 216.6887 - mae: 8.8877 - val_loss: 70.6688 - val_mae: 3.7733 - 3s/epoch - 6ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 70.66883 to 53.50232, saving model to best_lstm_model_lr.h5
# 425/425 - 2s - loss: 204.9345 - mae: 8.6282 - val_loss: 53.5023 - val_mae: 2.6884 - 2s/epoch - 6ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 53.50232
# 425/425 - 3s - loss: 200.7766 - mae: 8.5066 - val_loss: 99.7099 - val_mae: 4.9990 - 3s/epoch - 6ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 53.50232 to 46.84323, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 194.7053 - mae: 8.4604 - val_loss: 46.8432 - val_mae: 3.2383 - 3s/epoch - 6ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 46.84323
# 425/425 - 2s - loss: 189.8086 - mae: 8.2815 - val_loss: 54.1420 - val_mae: 3.6016 - 2s/epoch - 6ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 46.84323
# 425/425 - 2s - loss: 178.9206 - mae: 8.1185 - val_loss: 126.9021 - val_mae: 6.8937 - 2s/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 46.84323 to 38.73867, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 187.9119 - mae: 8.1616 - val_loss: 38.7387 - val_mae: 2.6604 - 3s/epoch - 6ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 38.73867
# 425/425 - 3s - loss: 170.7108 - mae: 7.8535 - val_loss: 47.5932 - val_mae: 3.7953 - 3s/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 38.73867
# 425/425 - 3s - loss: 171.8637 - mae: 7.8692 - val_loss: 51.6773 - val_mae: 3.7969 - 3s/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 38.73867 to 31.45055, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 167.8254 - mae: 7.8156 - val_loss: 31.4505 - val_mae: 3.3064 - 3s/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 31.45055
# 425/425 - 3s - loss: 172.5268 - mae: 7.8786 - val_loss: 88.2122 - val_mae: 4.1169 - 3s/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 31.45055
# 425/425 - 3s - loss: 160.1448 - mae: 7.5551 - val_loss: 56.9347 - val_mae: 5.4846 - 3s/epoch - 6ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 31.45055 to 29.37423, saving model to best_lstm_model_lr.h5
# 425/425 - 6s - loss: 170.5133 - mae: 7.9192 - val_loss: 29.3742 - val_mae: 2.7908 - 6s/epoch - 14ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 151.1378 - mae: 7.3949 - val_loss: 45.6075 - val_mae: 2.9762 - 3s/epoch - 8ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 152.3010 - mae: 7.3751 - val_loss: 62.1698 - val_mae: 4.4040 - 3s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 154.2502 - mae: 7.4885 - val_loss: 38.8518 - val_mae: 2.9038 - 3s/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 146.1407 - mae: 7.2274 - val_loss: 81.1422 - val_mae: 6.1803 - 3s/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 147.0677 - mae: 7.2350 - val_loss: 55.1525 - val_mae: 5.0290 - 3s/epoch - 7ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 135.4189 - mae: 6.9733 - val_loss: 40.1343 - val_mae: 3.2371 - 3s/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 29.37423
# 425/425 - 3s - loss: 135.4897 - mae: 6.9044 - val_loss: 45.7814 - val_mae: 4.2383 - 3s/epoch - 7ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 29.37423 to 25.97925, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 141.5501 - mae: 7.0966 - val_loss: 25.9792 - val_mae: 3.1114 - 3s/epoch - 8ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 25.97925 to 20.86554, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 138.8010 - mae: 7.0295 - val_loss: 20.8655 - val_mae: 2.5908 - 3s/epoch - 7ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 20.86554
# 425/425 - 3s - loss: 132.9180 - mae: 6.9145 - val_loss: 62.7106 - val_mae: 4.1438 - 3s/epoch - 7ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 20.86554 to 17.59064, saving model to best_lstm_model_lr.h5
# 425/425 - 3s - loss: 122.2624 - mae: 6.6422 - val_loss: 17.5906 - val_mae: 2.0350 - 3s/epoch - 8ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 123.8287 - mae: 6.6902 - val_loss: 70.6842 - val_mae: 4.8976 - 3s/epoch - 7ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 132.0196 - mae: 6.9366 - val_loss: 75.0337 - val_mae: 6.1607 - 3s/epoch - 7ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 125.4455 - mae: 6.7690 - val_loss: 63.5040 - val_mae: 4.0539 - 3s/epoch - 7ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 130.0377 - mae: 6.8375 - val_loss: 80.0596 - val_mae: 6.3840 - 3s/epoch - 7ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 120.1005 - mae: 6.5807 - val_loss: 23.8843 - val_mae: 2.9088 - 3s/epoch - 7ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 124.0878 - mae: 6.6983 - val_loss: 44.0243 - val_mae: 4.7060 - 3s/epoch - 7ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 114.5049 - mae: 6.4980 - val_loss: 26.4649 - val_mae: 2.3470 - 3s/epoch - 8ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 17.59064
# 425/425 - 3s - loss: 120.1839 - mae: 6.6660 - val_loss: 35.5675 - val_mae: 3.2687 - 3s/epoch - 7ms/step

# %% [markdown]
# # 학습과정 살펴보기

# %%
# 학습과정 그래프를 subplots와 twinx로 시각화
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.plot(history.history['loss'], label='Train Loss', color='tab:blue')
ax1.plot(history.history['val_loss'], label='Val Loss', color='tab:cyan')
ax1.set_ylabel('Loss')
ax1.set_xlabel('Epoch')
ax1.legend(loc='upper left')
ax1.grid(True)
ax2 = ax1.twinx()
ax2.plot(history.history['mae'], label='Train mae', color='tab:orange')
ax2.plot(history.history['val_mae'], label='Val mae', color='tab:red')
ax2.set_ylabel('MAE')
ax2.legend(loc='upper right')
plt.title('LSTM Training Loss & MAE (twin y-axis)')
plt.show()

# %% [markdown]
# # 모델의 평가

# %%
loss_and_mae = model_lstm.evaluate(X_test,y_test)
# Out:
# 6842/6842 [==============================] - 19s 3ms/step - loss: 14.9790 - mae: 2.0007

# %%
print('loss :',round(loss_and_mae[0],3))
print('MAE :',round(loss_and_mae[1],2))
# Out:
# loss : 14.979
# MAE : 2.0

# %% [markdown]
# # 모델의 저장

# %%
# 모델, 스케일러, 인코더, feature 리스트 저장
model_lstm.save('best_lstm_model_lr.h5')
joblib.dump(scaler, 'ENCODER_SCALER/scaler.pkl')
joblib.dump(le, 'ENCODER_SCALER/labelencoders.pkl')
joblib.dump(feature_cols, 'ENCODER_SCALER/featurecols.pkl')
joblib.dump(num_cols, 'ENCODER_SCALER/numcols.pkl')
# Out:
# ['ENCODER_SCALER/numcols.pkl']

# %% [markdown]
# # 모델의 사용

# %%
def DBMS_find_1year_ago_of_tomorrow():
    """
    오늘 기준으로 '내일'의 1년 전(같은 시각) 데이터를 DB에서 조회하는 함수
    """
    import pymysql
    from dotenv import load_dotenv
    import os
    import pandas as pd
    from datetime import datetime, timedelta

    load_dotenv()
    host = os.getenv('host')
    user = os.getenv('user')
    password = os.getenv('password')
    database = os.getenv('database')
    port = int(os.getenv('port', 3306))

    # 현재 시각
    now = datetime.now()

    # 내일 같은 시각
    tomorrow = now + timedelta(days=1)

    # 1년 전 내일 같은 시각
    dt_1y = tomorrow.replace(year=tomorrow.year - 1)

    # DB 컬럼명에 맞게 쿼리 작성 (연, 월, 일, 시)
    query =f"""
        SELECT *
        FROM basic_data
        WHERE year = {dt_1y.year}
          AND month = {dt_1y.month}
          AND day = {dt_1y.day}
          AND hour = {dt_1y.hour}"""

    try:
        connection = pymysql.connect(
            host=host,
            user=user,
            password=password,
            database=database,
            port=port,
            charset='utf8mb4',
            cursorclass=pymysql.cursors.DictCursor
        )
        with connection.cursor() as cursor:
            cursor.execute(query)
            data = cursor.fetchall()
            result_df = pd.DataFrame(data)
#             print(result_df)
            return result_df
    except Exception as e:
        print('에러 발생:', e)
        return None
    finally:
        try:
            connection.close()
        except:
            pass

# 사용법
DBMS_find_1year_ago_of_tomorrow()
# Out:
#     year  month  day  hour district            datetime  total_population  \
# 0   2024      6   29    17      강남구 2024-06-29 17:00:00            820475
# 1   2024      6   29    17      강동구 2024-06-29 17:00:00            479426
# 2   2024      6   29    17      강북구 2024-06-29 17:00:00            259919
# 3   2024      6   29    17      강서구 2024-06-29 17:00:00            516771
# 4   2024      6   29    17      관악구 2024-06-29 17:00:00            426542
# 5   2024      6   29    17      광진구 2024-06-29 17:00:00            359043
# 6   2024      6   29    17      구로구 2024-06-29 17:00:00            370174
# 7   2024      6   29    17      금천구 2024-06-29 17:00:00            192629
# 8   2024      6   29    17      노원구 2024-06-29 17:00:00            456559
# 9   2024      6   29    17      도봉구 2024-06-29 17:00:00            250194
# 10  2024      6   29    17     동대문구 2024-06-29 17:00:00            316874
# 11  2024      6   29    17      동작구 2024-06-29 17:00:00            350490
# 12  2024      6   29    17      마포구 2024-06-29 17:00:00            482881
# 13  2024      6   29    17     서대문구 2024-06-29 17:00:00            318965
# 14  2024      6   29    17      서초구 2024-06-29 17:00:00            566254
# 15  2024      6   29    17      성동구 2024-06-29 17:00:00            324081
# 16  2024      6   29    17      성북구 2024-06-29 17:00:00            381824
# 17  2024      6   29    17      송파구 2024-06-29 17:00:00            779555
# 18  2024      6   29    17      양천구 2024-06-29 17:00:00            357743
# 19  2024      6   29    17     영등포구 2024-06-29 17:00:00            482613
# 20  2024      6   29    17      용산구 2024-06-29 17:00:00            305253
# 21  2024      6   29    17      은평구 2024-06-29 17:00:00            404154
# 22  2024      6   29    17      종로구 2024-06-29 17:00:00            303832
# 23  2024      6   29    17       중구 2024-06-29 17:00:00            254325
# 24  2024      6   29    17      중랑구 2024-06-29 17:00:00            324615
#
#    season commute_time  weekend_flag  precipitation  temperature  humidity  \
# 0      여름           기타             1            6.0         23.8      97.0
# 1      여름           기타             1            5.0         23.8      95.0
# 2      여름           기타             1           10.0         23.7      95.0
# 3      여름           기타             1            6.5         24.0      94.0
# 4      여름           기타             1            6.5         23.4      94.0
# 5      여름           기타             1            6.0         23.8      97.0
# 6      여름           기타             1            5.5         24.4      94.0
# 7      여름           기타             1            5.5         24.4      94.0
# 8      여름           기타             1           10.0         23.7      95.0
# 9      여름           기타             1           10.0         23.7      95.0
# 10     여름           기타             1            6.5         24.1      96.0
# 11     여름           기타             1            6.0         24.8     100.0
# 12     여름           기타             1            6.5         24.5     100.0
# 13     여름           기타             1            9.5         24.2      96.0
# 14     여름           기타             1            3.0         24.1      94.0
# 15     여름           기타             1            6.0         23.8      97.0
# 16     여름           기타             1            9.5         24.2      96.0
# 17     여름           기타             1            4.5         24.7      94.0
# 18     여름           기타             1            6.5         24.0      94.0
# 19     여름           기타             1            6.5         24.5     100.0
# 20     여름           기타             1            6.0         23.8      97.0
# 21     여름           기타             1            6.5         23.4      96.0
# 22     여름           기타             1            9.5         24.2      96.0
# 23     여름           기타             1            9.5         24.2      96.0
# 24     여름           기타             1            7.0         24.0      96.0
#
#     wind_speed  rental_count
# 0          2.7           237
# 1          4.0           438
# 2          1.0           137
# 3          3.6           993
# 4          2.0           202
# 5          2.7           421
# 6          2.8           370
# 7          2.8           113
# 8          1.0           600
# 9          1.0           210
# 10         1.9           295
# 11         2.6           165
# 12         1.9           489
# 13         3.3           149
# 14         2.1           283
# 15         2.7           357
# 16         3.3           170
# 17         2.9           971
# 18         3.6           669
# 19         1.9           773
# 20         2.7           169
# 21         1.3           226
# 22         3.3           272
# 23         3.3           191
# 24         1.3           237

# %%
# 예측 함수
def predict_bike_demand(행정구, 강수, 습도, 풍속, 기온):
    """
    행정구명, 강수, 습도, 풍속, 기온을 입력받아
    해당 시간의 공공자전거 대여량 예측 클래스를 반환하는 함수
    """
    import pandas as pd
    import numpy as np
    import joblib
    from datetime import datetime, timedelta
    import holidays
    import tensorflow as tf

    le = joblib.load('ENCODER_SCALER/labelencoders.pkl')
    scaler = joblib.load('ENCODER_SCALER/scaler.pkl')
    feature_cols = joblib.load('ENCODER_SCALER/featurecols.pkl')
    num_cols = joblib.load('ENCODER_SCALER/numcols.pkl')
    model = tf.keras.models.load_model('best_lstm_model_lr.h5')

    now = datetime.now()
    년, 월, 일, 시 = now.year, now.month, now.day, now.hour
    요일 = now.weekday()
    주말구분 = 1 if 요일 >= 5 else 0
    kr_holidays = holidays.KR(years=[년])
    공휴일 = int(now.date() in kr_holidays)
    df_1y = DBMS_find_1year_ago_of_tomorrow()
    대여량_1년전 = df_1y[df_1y['district']==행정구].loc[:,'rental_count']
    총생활인구수_1년전 = df_1y[df_1y['district']==행정구].loc[:,'total_population']

    input_dict = {
        '행정구': le.transform([행정구])[0],
        '월': 월,
        '일': 일,
        '시': 시,
        '요일': 요일,
        '강수': 강수,
        '기온': 기온,
        '습도': 습도,
        '풍속': 풍속,
        '주말구분': 주말구분,
        '공휴일': 공휴일,
        '대여량_1년전': 대여량_1년전,
        '총생활인구수_1년전': 총생활인구수_1년전,
    }
    input_df = pd.DataFrame([input_dict])
    input_df[num_cols] = scaler.transform(input_df[num_cols])
    X_input = input_df[feature_cols].values
    X_input = np.expand_dims(X_input, axis=1)
    pred = model.predict(X_input,verbose=0)[0,0]
    return pred

# %%
pred = predict_bike_demand('강남구', 0.2, 60, 2.5, 21) # (행정구, 강수, 습도, 풍속, 기온)
print('25년 6월 29일 예측값', pred)
# Out:
# 25년 6월 29일 예측값 237.00577
